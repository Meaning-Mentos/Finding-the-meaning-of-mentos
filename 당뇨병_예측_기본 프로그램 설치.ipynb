# %% [markdown]
# <a href="https://colab.research.google.com/github/Meaning-Mentos/Finding-the-meaning-of-mentos/blob/main/%EB%8B%B9%EB%87%A8%EB%B3%91_%EC%98%88%EC%B8%A1_%EA%B8%B0%EB%B3%B8%20%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%A8%20%EC%84%A4%EC%B9%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#기본 3종 시리즈 판다, 넘파이, 메타플롯
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#사이킷런 라이브러리 불러오기, diabetes 관련
from sklearn.datasets import load_diabetes
#data.keys() <- 데이터 확인하게 도와주는 것
data = load_diabetes()    # 열의 이름 확인
print(data.feature_names)
data.keys()    #\ 어떤 키를 가지는지.

data['data'].shape
data['target'].shape
df = pd.DataFrame (data['data'], index=data['target'], columns=data['feature_names'])   #data = x index = y columns = 첫 열 설명

df.loc[df.age.isnull()]
#df.T # 행과 열 전환
#data는 x1,x2 -> index는 그 값의 결론 ax1 ? bx2 = index

#target은, 파이썬의 정답값을 뜻한다. 여기서는 당뇨병이 걸렸는지에 대해 설명한다.




#inv = pd.DataFrame(data.data)
#dev = pd.DataFrame(data.target)

#dataData = pd.concat([inv,dev], axis=1)

#inv.tail()
#x = dataData[['']]
#넘파이 랜덤 시드 지정기
#np.random.seed()
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']
# Empty DataFrame
# Columns: [age, sex, bmi, bp, s1, s2, s3, s4, s5, s6]
# Index: []
